# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('data/house_prices.csv')

# %% [markdown]
# <a id="contents"></a>
# ## Table of Contents
#
# <p>Seaborn</p>
# <ul>
# <li><a href="#pairplot">pairplot</a></li>
# </ul>

# %% [markdown]
# <a id='pairplot'></a>
# # seaborn pairplot: <a href='#contents'>Contents</a>
# Plot pairwise relationships in a dataset.

# %%
sns.pairplot(df[['bedrooms', 'bathrooms', 'area']]);
